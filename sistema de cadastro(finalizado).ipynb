# %%
opcao = 0
escolha = 0


def menu():
    global opcao,escolha
    print ("Bem vindo ao nosso Aplicativo \n")
    print ("Para começar, você preciso se cadastrar\n")
    escolha = int(input("Digite '1' para iniciar o cadastro ou digite '2' para sair: "))
    if escolha == 1:          
        opcao = int(input("""Digite '1' para STARTUP: \nDigite '2' para INVESTIDOR: \nDigite '3' para MENTOR: \n """))
        if opcao == 1:
            cadastro_usuario()
        elif opcao == 2:
            cadastro_investidor()
        elif opcao == 3:
            cadastro_mentor()
        else:
            print("Opção inválida")
            print("Por favor escolha umas das opções")
            return menu()
    elif escolha == 2:
        print("Obrigado")
    else:
        print("Opção inválida, retornando ao menu")
        return menu()
                    
def cadastro_usuario():
    nome = str(input("Digite o seu nome: \n "))
    email =str(input("Digite o seu E-mail: \n "))
    
    print("Agora precisamos da sua localidade")
    endereco = []
    cep = str(input("Digite o seu CEP: \n"))
    endereco.append(cep)
    rua = str(input("Digite a sua rua: \n"))
    endereco.append(rua)
    n = str(input("Digite o seu número da sua residencia: \n"))
    endereco.append(n)
    bairro = str(input("Digite o seu bairro: \n"))
    endereco.append(bairro)
    
    datanasc = []
    anonasc = int(input("Digite somente o ano do seu nascimento: "))
    if anonasc <= 2003 and anonasc >= 1900 :
        datanasc.append(anonasc)
    else:
        print("Você precisa ser maior de 18 anos, ok?")
        return menu()
    mesnasc = int(input("Digite somente o mes do seu nascimento: "))
    if mesnasc <= 12:
        datanasc.append(mesnasc)
    else:
        print("mês inválido")
        return menu()
    dianasc = int(input("Digite somente o dia do seu nascimento: "))
    if dianasc <= 31:
        datanasc.append(dianasc)
    else:
        print("dia inválido")
        return menu()
    
    projeto_s = str(input("Fale resumidamente sobre o seu projeto"))
    print("Grave um pitch de até 3 minutos para falar sobre o seu projeto")
    print("Dados amazenados, agora precisamos saber mais sobre o seu projeto\n")
    faturamento_s = int(input("Já possui algum faturamento?. Se sim digite '1' se não digite '2'. : "))
    if faturamento_s == 1:
        valor_s = float(input("Digite o valor:\n ")) 
    elif faturamento_s == 2:
        valor_s = 0
    else:
        print("opção inválida")
        return menu()

        
    print ("OK, Já estamos quase finalizando o seu cadastro, só falta a última pergunta")
    mentor_s = int(input("Deseja conectar-se com mentores/experts? Se sim digite '1' se não digite '2'\n: "))
    if mentor_s == 1 :
        valormentor_s = float(input("Digite o valor máximo a ser pago pela mentoria: "))
        print("Iremos sicronizar você a um mentor com um valor de mentoria sugerido de R$ {}\n".format(valormentor_s))
        print("cadastro finalizado!!!")
        print("Nome:\n {} ".format(nome))
        print("E-mail:\n {} ".format(email))
        print("Endereço:\n", endereco)
        print("Valor de faturamento no momento:\n {}".format(valor_s))
        print("Valor máximo a pagar por mentoria:\n ",valormentor_s)
        print("Obrigado")
            
    elif mentor_s == 2 :
        print ("Ok.\n")
        print("cadastro finalizado!!!")
        print("Nome:\n {} ".format(nome))
        print("E-mail:\n {} ".format(email))
        print("Endereço:\n ", endereco)
        print("Valor de faturamento no momento:\n {}".format(valor_s))
        print("Obrigado")
            
    else: 
        return menu()
                    
def cadastro_investidor():
    razao_social = str(input("Digite o seu nome: \n "))
    email =str(input("Digite o seu E-mail: \n "))
    cnpj =str(input("Digite o seu CNPJ: \n"))
    ie = int(input("Digite a inscrição estadual: \n"))
    
    print("Agora precisamos da sua localidade")
    endereco = []
    cep = str(input("Digite o seu CEP: \n"))
    endereco.append(cep)
    rua = str(input("Digite a sua rua: \n"))
    endereco.append(rua)
    n = str(input("Digite o seu número da sua residencia: \n"))
    endereco.append(n)
    bairro = str(input("Digite o seu bairro: \n"))
    endereco.append(bairro)
    
    print("Que bom que você veio até aqui, vamos inovar juntos ;)")
    motivo = str(input("Agora, me fala, qual o principal fator motivador que te trouxe até aqui?: \n"))
    tipo_de_projeto = str(input("Você tem preferencia por algum tipo de projeto? \n"))
    
    print("OK. Cadatro finalizado")
    print("Iremos sicronizar você a um projeto do seu interesse. Tipo de projeto de interesse: {}\n".format(tipo_de_projeto))
    print("Nome:\n {} ".format(razao_social))
    print("CNPJ:\n {}".format(cnpj))
    print("Inscrição Estadual:\n {}".format(ie))
    print("E-mail:\n {} ".format(email))
    print("Endereço:\n", endereco)
    print("Obrigado")
    
    
                    
                    
def cadastro_mentor():                    
    nome = str(input("Digite o seu nome: \n "))
    email =str(input("Digite o seu E-mail: \n "))
    
    print("Agora precisamos da sua localidade")
    endereco = []
    cep = str(input("Digite o seu CEP: \n"))
    endereco.append(cep)
    rua = str(input("Digite a sua rua: \n"))
    endereco.append(rua)
    n = str(input("Digite o seu número da sua residencia: \n"))
    endereco.append(n)
    bairro = str(input("Digite o seu bairro: \n"))
    endereco.append(bairro)
    
    datanasc = []
    anonasc = int(input("Digite somente o ano do seu nascimento: "))
    if anonasc <= 2003 and anonasc >= 1900 :
        datanasc.append(anonasc)
    else:
        print("Você precisa ser maior de 18 anos, ok?")
        return menu()
    mesnasc = int(input("Digite somente o mes do seu nascimento: "))
    if mesnasc <= 12:
        datanasc.append(mesnasc)
    else:
        print("mês inválido")
        return menu()
    dianasc = int(input("Digite somente o dia do seu nascimento: "))
    if dianasc <= 31:
        datanasc.append(dianasc)
    else:
        print("dia inválido")
        return menu()
    print("OK, dados armazenados")
    print("Precisamos saber mais sobre você")
    especialidade = str(input("Qual a sua especialidade?: \n"))
    valor_m = int(input("Qual o valor você gostaria de receber por cada mentoria? \n 'valor cobrado por sessão' :R$ \n"))
    valor_pitch = int(input("Qual o valor você cobra para avaliar cada pitch ? : R$ \n"))
    
    print("Cadastro finalizado")
    print("Nome:\n {} ".format(nome))
    print("E-mail:\n {} ".format(email))
    print("Endereço:\n", endereco)
    print("Expecialista de ou na área de:\n {}".format(especialidade))
    print("Valor a ser cobrado a cada sessão:\n R$ {} ".format(valor_m))
    print("Valor a ser cobrado a cada avaliação de PITCH:\n R$ {} ".format(valor_pitch))
    print("")
    
    print("Obrigado")
    
    
    


menu()
# Out:
# Bem vindo ao nosso Aplicativo
#
# Para começar, você preciso se cadastrar
#
# Digite '1' para iniciar o cadastro ou digite '2' para sair: 1
# Digite '1' para STARTUP:
# Digite '2' para INVESTIDOR:
# Digite '3' para MENTOR:
#  3
# Digite o seu nome:
#  Patrícia Reis
# Digite o seu E-mail:
#  patricia.reis@gmail.com
# Agora precisamos da sua localidade
# Digite o seu CEP:
# 09990-070
# Digite a sua rua:
# Rua Jardins
# Digite o seu número da sua residencia:
# 55
# Digite o seu bairro:
# JD. Baleia
# Digite somente o ano do seu nascimento: 2000
# Digite somente o mes do seu nascimento: 12
# Digite somente o dia do seu nascimento: 13
# OK, dados armazenados
# Precisamos saber mais sobre você
# Qual a sua especialidade?:
# Cyber Security
# Qual o valor você gostaria de receber por cada mentoria?
#  'valor cobrado por sessão' :R$
# 600
# Qual o valor você cobra para avaliar cada pitch ? : R$
# 100
# Cadastro finalizado
# Nome:
#  Patrícia Reis
# E-mail:
#  patricia.reis@gmail.com
# ...
